# %%
from copy import deepcopy
from mysklearn import myutils, myclassifiers, mypytable

CLASSES = ["Pastry","Z_Scratch","K_Scratch","Stains","Dirtiness","Bumps","Other_Faults"]
CLASS_HEADER = "Class"

data = mypytable.MyPyTable().load_from_file("plate-data.csv")
data = myutils.onehot_to_categorical(data, CLASSES)
features = deepcopy(data.column_names)
features.pop(features.index(CLASS_HEADER))
# Out:
# 'Class'

# %%
binned = mypytable.MyPyTable(data.column_names, data.data)

for feature in features:
    if feature == "TypeOfSteel_A300" or feature == "TypeOfSteel_A400":
        continue

    col_values = data.get_column(feature)
    binned_col = myutils.equal_width_bin(col_values, 10)
    binned.replace_column(feature, binned_col)

# %%
normalized = mypytable.MyPyTable(data.column_names, data.data)

for feature in features:
    if feature == "TypeOfSteel_A300" or feature == "TypeOfSteel_A400":
        continue

    col_values = data.get_column(feature)
    normalized_col = myutils.normalize_list(col_values)
    normalized.replace_column(feature, normalized_col)

# %%
myutils.stratified_kfold_tester(myclassifiers.MyDecisionTreeClassifier(len(features)),
                                binned,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# Fold #2 started
# Fold #3 started
# /home/damon/Documents/CPSC322/cpsc-322-finalproject/mysklearn/myclassifiers.py:333: RuntimeWarning: divide by zero encountered in log2
#   entropy += -sum(p * np.log2(p) for p in probs.values()) * \
# /home/damon/Documents/CPSC322/cpsc-322-finalproject/mysklearn/myclassifiers.py:333: RuntimeWarning: invalid value encountered in scalar multiply
#   entropy += -sum(p * np.log2(p) for p in probs.values()) * \
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# Confusion Matrix
#                 Pastry    Z_Scratch    K_Scratch    Stains    Dirtiness    Bumps    Other_Faults
# ------------  --------  -----------  -----------  --------  -----------  -------  --------------
# Pastry               0            0           42         0            0        5             111
# Z_Scratch            0            0          129         0            0        0              61
# K_Scratch            0            0          338         0            0        8              45
# Stains               0            0            0         0            0        7              65
# Dirtiness            0            0            4         0            0        5              46
# Bumps                0            0           48         0            0       18             336
# Other_Faults         0            0          158         0            0       37             478
# accuracy: 0.42967542503863987
# precision: 0.42967542503863987
# f1 score: 0.42967542503863987
# recall: 0.42967542503863987
#                 precision     recall    f1-score    support
# ------------  -----------  ---------  ----------  ---------
# Pastry           0         0           0                158
# Z_Scratch        0         0           0                190
# K_Scratch        0.470097  0.86445     0.609009         391
# Stains           0         0           0                 72
# Dirtiness        0         0           0                 55
# Bumps            0.225     0.0447761   0.0746888        402
# Other_Faults     0.418564  0.710253    0.526722         673
# micro avg        0.429675  0.429675    0.429675        1941
# macro avg        0.159094  0.231354    0.172917        1941
# weighted avg     0.286425  0.429675    0.320779        1941
# None

# %%
myutils.stratified_kfold_tester(myclassifiers.MyKNeighborsClassifier(n_neighbors=3),
                                normalized,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# Fold #2 started
# Fold #3 started
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# Confusion Matrix
#                 Pastry    Z_Scratch    K_Scratch    Stains    Dirtiness    Bumps    Other_Faults
# ------------  --------  -----------  -----------  --------  -----------  -------  --------------
# Pastry              69            3            0         0            1       37              48
# Z_Scratch            1          162            5         0            1        9              12
# K_Scratch            1            1          367         3            0        5              14
# Stains               0            0            0        65            0        2               5
# Dirtiness            1            0            0         0           41        7               6
# Bumps                9           11            2         6            5      259             110
# Other_Faults        33           31           13         7           14      169             406
# accuracy: 0.7053065430190624
# precision: 0.7053065430190624
# f1 score: 0.7053065430190624
# recall: 0.7053065430190624
#                 precision    recall    f1-score    support
# ------------  -----------  --------  ----------  ---------
# Pastry           0.605263  0.436709    0.507353        158
# Z_Scratch        0.778846  0.852632    0.81407         190
# K_Scratch        0.94832   0.938619    0.943445        391
# Stains           0.802469  0.902778    0.849673         72
# Dirtiness        0.66129   0.745455    0.700855         55
# Bumps            0.530738  0.644279    0.582022        402
# Other_Faults     0.675541  0.603269    0.637363        673
# micro avg        0.705307  0.705307    0.705307       1941
# macro avg        0.714638  0.731963    0.719254       1941
# weighted avg     0.709196  0.705307    0.703948       1941
# None

# %%
myutils.stratified_kfold_tester(myclassifiers.MyRandomForestClassifier(10, 5, 5),
                                binned,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# Fold #2 started
# Fold #3 started
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# Confusion Matrix
#                 Pastry    Z_Scratch    K_Scratch    Stains    Dirtiness    Bumps    Other_Faults
# ------------  --------  -----------  -----------  --------  -----------  -------  --------------
# Pastry               0            0           42         0            0        5             111
# Z_Scratch            0            0          129         0            0        0              61
# K_Scratch            0            0          338         0            0       13              40
# Stains               0            0            0         0            0        9              63
# Dirtiness            0            0            4         0            0        8              43
# Bumps                0            0           48         0            0       47             307
# Other_Faults         0            0          158         0            0       59             456
# accuracy: 0.43328181349819683
# precision: 0.43328181349819683
# f1 score: 0.43328181349819683
# recall: 0.43328181349819683
#                 precision    recall    f1-score    support
# ------------  -----------  --------  ----------  ---------
# Pastry           0         0           0               158
# Z_Scratch        0         0           0               190
# K_Scratch        0.470097  0.86445     0.609009        391
# Stains           0         0           0                72
# Dirtiness        0         0           0                55
# Bumps            0.333333  0.116915    0.173112        402
# Other_Faults     0.421832  0.677563    0.519954        673
# micro avg        0.433282  0.433282    0.433282       1941
# macro avg        0.175037  0.23699     0.186011       1941
# weighted avg     0.309995  0.433282    0.338817       1941
# None
