# %%
from copy import deepcopy
from mysklearn import myutils, myclassifiers, mypytable

CLASSES = ["Pastry","Z_Scratch","K_Scratch","Stains","Dirtiness","Bumps","Other_Faults"]
CLASS_HEADER = "Class"

data = mypytable.MyPyTable().load_from_file("plate-data.csv")
data = myutils.onehot_to_categorical(data, CLASSES)
features = deepcopy(data.column_names)
features.pop(features.index(CLASS_HEADER))
# Out:
# 'Class'

# %%
binned = mypytable.MyPyTable(data.column_names, data.data)

for feature in features:
    if feature == "TypeOfSteel_A300" or feature == "TypeOfSteel_A400":
        continue

    col_values = data.get_column(feature)
    binned_col = myutils.equal_width_bin(col_values, 10)
    binned.replace_column(feature, binned_col)

# %%
myutils.stratified_kfold_tester(myclassifiers.MyDecisionTreeClassifier(len(features)),
                                binned,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# Fold #2 started
# Fold #3 started
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# accuracy: 0.42761463163317875
# precision: 0.42761463163317875
# f1 score: 0.42761463163317875
# recall: 0.42761463163317875
#                 precision     recall    f1-score    support
# ------------  -----------  ---------  ----------  ---------
# Pastry           0         0           0                158
# Z_Scratch        0         0           0                190
# K_Scratch        0.470097  0.86445     0.609009         391
# Stains           0         0           0                 72
# Dirtiness        0         0           0                 55
# Bumps            0.193548  0.0298507   0.0517241        402
# Other_Faults     0.413793  0.713224    0.523732         673
# micro avg        0.427615  0.427615    0.427615        1941
# macro avg        0.15392   0.229646    0.169209        1941
# weighted avg     0.278257  0.427615    0.314986        1941
# None

# %%
myutils.stratified_kfold_tester(myclassifiers.MyKNeighborsClassifier(n_neighbors=2),
                                data,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# Fold #2 started
# Fold #3 started
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# accuracy: 0.401854714064915
# precision: 0.401854714064915
# f1 score: 0.401854714064915
# recall: 0.401854714064915
#                 precision      recall    f1-score    support
# ------------  -----------  ----------  ----------  ---------
# Pastry          0.0958904  0.0443038   0.0606061         158
# Z_Scratch       0.0454545  0.00526316  0.00943396        190
# K_Scratch       0.691974   0.815857    0.748826          391
# Stains          0          0           0                  72
# Dirtiness       0.294872   0.418182    0.345865           55
# Bumps           0.289291   0.517413    0.371097          402
# Other_Faults    0.387435   0.329866    0.35634           673
# micro avg       0.401855   0.401855    0.401855         1941
# macro avg       0.257845   0.304412    0.27031          1941
# weighted avg    0.354253   0.401855    0.366914         1941
# None

# %%
myutils.stratified_kfold_tester(myclassifiers.MyRandomForestClassifier(10, 5, 5),
                                binned,
                                CLASS_HEADER,
                                CLASSES,
                                10)
# Out:
# Setup complete
# Fold #1 started
# /home/damon/Documents/CPSC322/cpsc-322-finalproject/mysklearn/myclassifiers.py:333: RuntimeWarning: divide by zero encountered in log2
#   entropy += -sum(p * np.log2(p) for p in probs.values()) * \
# /home/damon/Documents/CPSC322/cpsc-322-finalproject/mysklearn/myclassifiers.py:333: RuntimeWarning: invalid value encountered in scalar multiply
#   entropy += -sum(p * np.log2(p) for p in probs.values()) * \
# Fold #2 started
# Fold #3 started
# Fold #4 started
# Fold #5 started
# Fold #6 started
# Fold #7 started
# Fold #8 started
# Fold #9 started
# Fold #10 started
# accuracy: 0.44049459041731065
# precision: 0.44049459041731065
# f1 score: 0.44049459041731065
# recall: 0.44049459041731065
#                 precision     recall    f1-score    support
# ------------  -----------  ---------  ----------  ---------
# Pastry           0         0           0                158
# Z_Scratch        0         0           0                190
# K_Scratch        0.470097  0.86445     0.609009         391
# Stains           0         0           0                 72
# Dirtiness        0         0           0                 55
# Bumps            0.377049  0.0572139   0.0993521        402
# Other_Faults     0.425495  0.734027    0.538713         673
# micro avg        0.440495  0.440495    0.440495        1941
# macro avg        0.181806  0.236527    0.178153        1941
# weighted avg     0.320319  0.440495    0.330044        1941
# None
